# %% [markdown]
# <a href="https://colab.research.google.com/github/zulfanakbar/PCVK/blob/main/TugasWeek2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

# Accessing My Google Drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io 
import matplotlib.pyplot as plt
import numpy as np
zulfan = cv.imread('/content/drive/MyDrive/FOOTBALL/gie football-8532.jpg')
plt.imshow(zulfan)

# %%
zulfan2 = zulfan
zulfan3 = cv.cvtColor(zulfan,cv.COLOR_BGR2RGB) #konversi channel BGR -> RGB
plt.imshow(zulfan3)

# %%
#1. Tampilkan image dalam channel Red-Green dan Green-Blue saja!
zulfan4 = zulfan3
#Red - Green
zulfan4[:,:,0] = np.zeros([zulfan4.shape[0], zulfan4.shape[1]])
plt.imshow(zulfan4)

# %%
#Blue - Green
zulfan5 = zulfan3

zulfan5[:,:,2] = np.zeros([zulfan5.shape[0], zulfan5.shape[1]])
plt.imshow(zulfan5)

# %%
#2. Tampilkan image baris ke 10-100, kolom 10-100!
img2 = img
img3 = cv.cvtColor(img,cv.COLOR_BGR2RGB)
plt.imshow(img3[10:100, 10:100])

# %%
#3. Tampilkan image baris ke 5-30, semua kolom, channel Green saja!
plt.imshow(img5[5:30])

# %%
#4. Buat 5 kotak berbagai ukuran dan warna yang berbeda dalam satu image. disarankan menggunakan bilangan acak/random!
import random


img6 = cv.cvtColor(img,cv.COLOR_BGR2RGB)
for x in range(5):
  startp = random.randint(0,350)
  endp = random.randint(0,350)

  w1 = random.randint(80,200)
  w2 = random.randint(100,100)
  w3 = random.randint(50,123)
  w4 = random.randint(34,187)
  w5 = random.randint(46,215)
  start_point = (startp , startp) 
    
  end_point = (endp, endp) 
    
  warna = (w1, w2, w3, w4, w5) 
    
  thickness = 7
    
  img6 = cv.rectangle(img3, start_point, end_point, color, thickness) 
    
# Displaying the image  
plt.imshow(img6)

# %%
#5. Tampilkan image dengan posisi terbalik!
img7 = cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGB),0)
plt.imshow(img7)

# %%
#Berdasarkan praktikum bagian 3 dan 4 kerjakan beberapa tugas berikut :
#6. Buat rectangle dan circle pada bagian wajah dari image kitten!

zulfan = cv.imread('/content/drive/MyDrive/FOOTBALL/gie football-8532.jpg')
fig = plt.figure(figsize = (10,5))
ax = fig.add_subplot(111) 

cv.rectangle(zulfan,pt1=(2000,800),pt2=(2000,1250),color=(0,300,0), thickness=2)

cv.circle(zulfan,center=(2000,800),radius=500,color=(255,0,0),thickness=2)

ax.imshow(zulfan)

# %%
#7. Buat rectangle pada bagian sudut bawah kiri channel B pada color space RGB dari citra kitten01.jpg!
zulfan = cv.imread('/content/drive/MyDrive/FOOTBALL/gie football-8532.jpg')

fig = plt.figure(figsize = (10,10))
ax = fig.add_subplot(111) 

cv.rectangle(zulfan,pt1=(50,150),pt2=(125,125),color=(0,255,0), thickness=2)

cv.circle(zulfan,center=(90,150),radius=50,color=(255,0,0),thickness=2)

cv.rectangle(zulfan,pt1=(10,270),pt2=(100,290),color=(0,255,0), thickness=2)

ax.imshow(zulfan)
